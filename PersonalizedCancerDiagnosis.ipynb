# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>
#
# <h1>1. Business Problem</h1>
# <h2>1.1. Description</h2>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
#
# *   List item
# *   List item
#
#
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>
#
# <h2>1.2. Source/Useful Links</h2>
# Some articles and reference blogs about the problem statement.
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8
#
# <h2>1.3. Real-world/Business objectives and constraints.</h2>
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.
#
# <h1>2. Machine Learning Problem Formulation</h1>
# <h2>2.1. Data</h2>
# <h3>2.1.1. Data Overview</h3>
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>
#
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>
# <h3>2.2.1. Type of Machine Learning Problem</h3>
# <p>
#     There are nine different classes a genetic mutation can be classified into => Multi class classification problem
# </p>
# <h3>2.2.2. Performance Metric</h3>
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix
#
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.
#
# <h2>2.3. Train, CV and Test Datasets</h2>
# Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import numpy as np
from scipy.sparse import hstack

import matplotlib.pyplot as plt
import seaborn as sns

import re
import time
import math
from collections import Counter, defaultdict
import warnings
warnings.filterwarnings("ignore")

from imblearn.over_sampling import SMOTE

from nltk.corpus import stopwords

from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, log_loss, normalized_mutual_info_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier

from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('data/training_variants')

print(data.shape)
print('Features : ', data.columns.values)
data.head()
# Out:
# (3321, 4)
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text = pd.read_csv("data/training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)

print(data_text.shape)
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# (3321, 2)
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hamza\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))

def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
# text processing stage.
start_time = time.time()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.time() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 49.21073508262634 seconds

# %%
# Merging both gene_variations and text data based on ID
result = pd.merge(data, data_text, on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] + ' ' + result['Variation']

# %%
result[result['ID'] == 1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values

# Any space replace by '_'
result['Gene']      = result['Gene'].str.replace('\s+', '_')
result['Variation'] = result['Variation'].str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
def display_distribution(class_distribution, split_data_type, data_shape):
    my_colors = 'rgbkymc'
    train_class_distribution.plot(kind='bar')
    plt.xlabel('Class')
    plt.ylabel('Data points per Class')
    plt.title(f'Distribution of yi in {split_data_type} data')
    plt.grid()
    plt.show()
    
    # ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
    # -(class_distribution.values): the minus sign will give us in decreasing order
    sorted_yi = np.argsort(-class_distribution.values)
    for i in sorted_yi:
        print('Number of data points in class', i+1, ':',class_distribution.values[i], '(', np.round((class_distribution.values[i]/data_shape*100), 3), '%)')

    print('-'*80)

##########################################################    
##########################################################

# It returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sort_index()
display_distribution(class_distribution=train_class_distribution, split_data_type="train", data_shape=train_df.shape[0])

test_class_distribution = test_df['Class'].value_counts().sort_index()
display_distribution(class_distribution=test_class_distribution, split_data_type="test", data_shape=test_df.shape[0])

cv_class_distribution = cv_df['Class'].value_counts().sort_index()
display_distribution(class_distribution=cv_class_distribution, split_data_type="cv", data_shape=cv_df.shape[0])
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)
# --------------------------------------------------------------------------------

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
def random_model_test(split_data_type, df_splitted, test_data):
    # we need to generate 9 numbers and the sum of numbers should be 1
    # one solution is to genarate 9 numbers and divide each of the numbers by their sum
    # ref: https://stackoverflow.com/a/18662466/4084039
    data_len = df_splitted.shape[0]
    
    # we create a output array that has exactly same size as the data
    predicted_y = np.zeros((data_len,9))
    for i in range(data_len):
        rand_probs = np.random.rand(1, 9)
        predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
    print(f"Log loss on {split_data_type} Data using Random Model", log_loss(test_data, predicted_y, eps=1e-15))
    
    if split_data_type == "test":
        predicted_y = np.argmax(predicted_y, axis=1)
        plot_confusion_matrix(test_data, predicted_y+1)
    
############################################
############################################
random_model_test(split_data_type="CV", df_splitted=cv_df, test_data=y_cv)
random_model_test(split_data_type="test", df_splitted=test_df, test_data=y_test)
# Out:
# Log loss on CV Data using Random Model 2.4712158610985666
# Log loss on test Data using Random Model 2.4849347600754013
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# #### CONCLUSION
# Log loss on randon model = (2.437 CV) to (2.472 test)
#
# Since, log-loss= [0, inf)</br>
# thus, best model should give log-loss less than 2.437 atleast.

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# Code for Laplace smoothing.
# alpha/lambda : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']

# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

def get_gv_fea_dict(alpha, feature, df):
    """get_gv_fea_dict: Get gene varaition feature dict"""
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 231
# BRCA1     170
# TP53      110
# PTEN       92
# EGFR       84
# BRCA2      76
# KIT        65
# BRAF       61
# ALK        44
# PDGFRA     43
# ERBB2      37
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 231 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### CONCLUSION
# 1. One of the gene has occurance of 8%.
# 2. Few gene have high as well as low frequency.

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# #### CONCLUSION
# 1. 60 to 65 genes haves 80% ratio while rest of 20% has remaining genes.

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b> As gene feature is cardinal, therefore; there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding (Distance related algo i.e; log reg, lr-svm, knn, etc)</li><li>Response coding (non-linear model i.e; Tree algos, kernel-svm, etc)</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %% [markdown]
# ### Response coding

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %% [markdown]
# ### One-hotcode encoding

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 85        RIT1
# 913     PDGFRA
# 577      SMAD4
# 3307     RUNX1
# 314       ELF3
# Name: Gene, dtype: object

# %%
print(gene_vectorizer.get_feature_names()[:10])
# Out:
# ['abl1', 'acvr1', 'ago2', 'akt1', 'akt2', 'akt3', 'alk', 'apc', 'ar', 'araf']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 231)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()

best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.2468625446863884
# For values of alpha =  0.0001 The log loss is: 1.2321051772619604
# For values of alpha =  0.001 The log loss is: 1.2670272286531403
# For values of alpha =  0.01 The log loss is: 1.3729949910182593
# For values of alpha =  0.1 The log loss is: 1.445133582799856
# For values of alpha =  1 The log loss is: 1.4766091079435117
# For values of best alpha =  0.0001 The train log loss is: 0.9968424206781976
# For values of best alpha =  0.0001 The cross validation log loss is: 1.2321051772619604
# For values of best alpha =  0.0001 The test log loss is: 1.1366618134709396

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the 231  genes in train dataset?
# Ans
# 1. In test data 648 out of 665 : 97.44360902255639
# 2. In cross validation data 514 out of  532 : 96.61654135338345

# %% [markdown]
# #### CONCLUSION: Gene variable
#
# 1. Log loss
# train: 0.98</br>
# cv:    1.17</br>
# test:  1.23</br>
#
# <b>Result:</b> As logloss value is less than random model.</br>
#     - gene onehotcodeencoding variable = IMPORTANT
#
# 2. Convergence/overlapping of data
# cv:   96.69</br>
# test: 96.99</br>
#
# <b>Result:</b> As test & cv data has convergence very high.</br>
#     - gene onehotcodeencoding variable = STABLE

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1934
# Truncating_Mutations    57
# Amplification           47
# Deletion                43
# Fusions                 22
# Overexpression           4
# G12V                     3
# V321M                    2
# E17K                     2
# T58I                     2
# G12A                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1934 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### CONCLUSION:
# 1. Most of the data points have frequency of 1 or 2.

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02683616 0.04896422 0.06920904 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# #### CONCLUSION:
# 1. 80% of variation has 1500 variations approx.

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1962)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7071490112792327
# For values of alpha =  0.0001 The log loss is: 1.701781162818412
# For values of alpha =  0.001 The log loss is: 1.7038293430823819
# For values of alpha =  0.01 The log loss is: 1.712677849582452
# For values of alpha =  0.1 The log loss is: 1.727155794283301
# For values of alpha =  1 The log loss is: 1.7293844578483377
# For values of best alpha =  0.0001 The train log loss is: 0.7224432159219478
# For values of best alpha =  0.0001 The cross validation log loss is: 1.701781162818412
# For values of best alpha =  0.0001 The test log loss is: 1.6888722732074155

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " variation in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1934  variation in test and cross validation data sets?
# Ans
# 1. In test data 72 out of 665 : 10.827067669172932
# 2. In cross validation data 50 out of  532 : 9.398496240601503

# %% [markdown]
# #### CONCLUSION: Variation variable
#
# 1. Log loss
# train: 0.70</br>
# cv:    1.70</br>
# test:  1.69</br>
#
# <b>Result:</b> As logloss value is less than random model but fluctions in all datasets.</br>
#     - gene onehotcodeencoding variable = IMPORTANT
#
# 2. Convergence/overlapping of data</br>
# cv:   10.82</br>
# test:  10.90</br>
#
# <b>Result:</b> As test & cv data has convergence very high.</br>
#     - gene onehotcodeencoding variable = LESS STABLE

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
# One hotcode encoding == BOW in nlp 
text_vectorizer = CountVectorizer(min_df=3)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))

print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 52200

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)

confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur[:5]))
# Out:
# Counter({148916: 1, 114158: 1, 77324: 1, 66921: 1, 65596: 1})

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3586268325684254
# For values of alpha =  0.0001 The log loss is: 1.260799709985029
# For values of alpha =  0.001 The log loss is: 1.2410919500458222
# For values of alpha =  0.01 The log loss is: 1.311199489750221
# For values of alpha =  0.1 The log loss is: 1.4563899992407447
# For values of alpha =  1 The log loss is: 1.6518711591022177
# For values of best alpha =  0.001 The train log loss is: 0.639703165965964
# For values of best alpha =  0.001 The cross validation log loss is: 1.2410919500458222
# For values of best alpha =  0.001 The test log loss is: 1.1120948375989241

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 96.611 % of word of test data appeared in train data
# 96.9 % of word of Cross Validation appeared in train data

# %% [markdown]
# #### CONCLUSION: text variable
#
# 1. Log loss</br>
# train: 0.655</br>
# cv:    1.145</br>
# test:  1.075</br>
#
# <b>Result:</b> As logloss value is less than random model but fluctions in all datasets.</br>
#     - gene onehotcodeencoding variable = IMPORTANT</br>
#
# 2. Convergence/overlapping of data</br>
# cv:   96.415</br>
# test: 97.764</br>
#
# <b>Result:</b> As test & cv data has convergence very high.</br>
#     - gene onehotcodeencoding variable = STABLE

# %% [markdown]
# #### CONCLUSION: All variables
#
# 1. Log loss -> To check imp of variable
#
# |            | gene   | variation   | text   |
# |------------|--------|-------------|--------|
# | train      | 0.98   | 0.70        | 0.65   |
# | cv         | 1.17   | 1.70        | 1.14   |
# | test       | 1.23   | 1.69        | 1.07   |
# | Importance | HIGH   | LESS        | HIGH   |
#
# 2. Data convergence(overlap of data) -> To check stability of variables
#
# |           | cv    | test  | convergence | Stability |
# |-----------|-------|-------|-------------|-----------|
# | gene      | 96.69 | 96.99 | v. high     | V. HIGH   |
# | variation | 10.82 | 10.90 | v. low      | L. LOW    |
# | text      | 96.41 | 97.76 | v. high     | V. HIGH   |
#
#
# <b>Result</b>:
#
# | variables | Importance order |
# |-----------|------------------|
# |    text   |         1        |
# |    gene   |         2        |
# | variation |         3        |

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
# Data preparation for ML models.

# Misc. functionns for ML models

def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 54393)
# (number of data points * number of features) in test data =  (665, 54393)
# (number of data points * number of features) in cross validation data = (532, 54393)

# %%
train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.3351916039193428
# for alpha = 0.0001
# Log Loss : 1.330195772971306
# for alpha = 0.001
# Log Loss : 1.304073421431442
# for alpha = 0.1
# Log Loss : 1.24959396339106
# for alpha = 1
# Log Loss : 1.2936381146543656
# for alpha = 10
# Log Loss : 1.431284610354075
# for alpha = 100
# Log Loss : 1.4022622288632673
# for alpha = 1000
# Log Loss : 1.363085014461476
# For values of best alpha =  0.1 The train log loss is: 0.8724403937572163
# For values of best alpha =  0.1 The cross validation log loss is: 1.24959396339106
# For values of best alpha =  0.1 The test log loss is: 1.2368919901191786

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.24959396339106
# Number of missclassified point : 0.37781954887218044
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# #### CONCLUSION
# 1. Confusion matrix:</br>
#     a. It's hard to interpretate as we have more points 1, 2, 4, 7 & less in 8 & 9.
#
# 2. Precision matrix:</br>
#     a. Diagonal elements ideally should be 1.</br>
#     b. All points predicted to be class 1, 55.3% predicted to be class 1 and same interpretation for other classes.</br>
#     c. Anomaly case: Points predicted class 2 & 3 about 24.4% & 33.3% respectively but  actually belongs to class 7.</br>
#     d. Anomaly case: Points predicted class 1 about 19.4%  but actually belongs to class 4.</br>
#
# 3. Recall matrix:</br>
#     a. All points which belongs to class 7, 80.4% classified as class 7.
#     b. Anomaly case: All points belongs to class 8, 66.7%, 33.3% & 0% classified as class 1, 7       & 8 respectively.
#
# <b>RESULT:</b></br>
#
# | org | pred |
# |-----|------|
# | 1   | 4, 5 |
# | 2   | 7    |
# | 3   | 4    |
# | 4   | 1    |
# | 7   | 2, 3 |
# | 8   | 1, 7 |
# | 6   | 7    |

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])

indices=np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0736 0.0701 0.0118 0.6512 0.0341 0.0305 0.1209 0.0041 0.0038]]
# Actual Class : 4
# --------------------------------------------------
# Out of the top  100  features  0 are present in query point

# %%
print(test_df['TEXT'].iloc[test_point_index][:500])
print("="*50)
print(no_feature)
print(test_df['Gene'].iloc[test_point_index])
print(test_df['Variation'].iloc[test_point_index])
print(clf.coef_.shape)
# Out:
# ras p21 interacts directly catalytic subunit phosphatidylinositol 3 0h kinase gtp dependent manner ras effector site vivo dominant negative ras mutant n17 inhibits growth factor induced production 3 phosphorylated phosphoinositides pc12 cells transfection ras raf cos cells results large elevation level lipids therefore ras probably regulate phosphatidylinositol 3 0h kinase providing point divergence signalling pathways downstream ras ras proteins key regulators cell growth functions elucidation
# ==================================================
# 100
# NF1
# K1436Q
# (9, 54393)

# %%
indices=np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
indices[0]
# Out:
# array([    0, 28798, 28797, 28796, 28787, 28786, 28785, 28784, 28783,
#        28782, 28779, 28777, 28772, 28767, 28764, 28762, 28751, 28750,
#        28746, 28745, 28738, 28727, 28723, 28720, 28711, 28709, 28800,
#        28801, 28802, 28804, 28871, 28865, 28864, 28862, 28860, 28858,
#        28856, 28851, 28849, 28838, 28836, 28835, 28707, 28834, 28828,
#        28827, 28823, 28822, 28818, 28816, 28814, 28811, 28809, 28808,
#        28807, 28806, 28833, 28703, 28702, 28699, 28615, 28614, 28612,
#        28606, 28596, 28592, 28585, 28573, 28566, 28559, 28557, 28552,
#        28618, 28545, 28543, 28542, 28541, 28540, 28534, 28532, 28529,
#        28528, 28524, 28519, 28518, 28515, 28544, 28873, 28621, 28630,
#        28694, 28691, 28690, 28688, 28686, 28683, 28681, 28668, 28667,
#        28663], dtype=int64)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer()
    var_count_vec = CountVectorizer()
    text_count_vec = CountVectorizer(min_df=3)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
for i in range(1):
    test_point_index = i
    no_feature = 10
    predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
    print("Predicted Class :", predicted_cls[0])
    print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
    print("Actual Class :", test_y[test_point_index])
    indices=np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:]
    print("-"*50)
    get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.5238 0.0848 0.0143 0.1431 0.0418 0.0368 0.1458 0.0049 0.0046]]
# Actual Class : 4
# --------------------------------------------------
# 1586 Text feature [hifs] present in test data point [True]
# 1661 Text feature [henceforth] present in test data point [True]
# 3476 Text feature [l188v] present in test data point [True]
# 4941 Text feature [classed] present in test data point [True]
# 8589 Text feature [s80n] present in test data point [True]
# 11735 Text feature [pcc] present in test data point [True]
# 11759 Text feature [pccs] present in test data point [True]
# 12381 Text feature [nucleates] present in test data point [True]
# 13577 Text feature [popmusic] present in test data point [True]
# 15365 Text feature [0132] present in test data point [True]
# 16612 Text feature [2105] present in test data point [True]
# 16879 Text feature [bioc] present in test data point [True]
# 17018 Text feature [beatmusic] present in test data point [True]
# 17234 Text feature [brien] present in test data point [True]
# 20993 Text feature [hif2] present in test data point [True]
# 21248 Text feature [hif1] present in test data point [True]
# 22010 Text feature [pubmed] present in test data point [True]
# 22312 Text feature [trained] present in test data point [True]
# 22316 Text feature [s14] present in test data point [True]
# 22365 Text feature [1471] present in test data point [True]
# 22456 Text feature [vcb] present in test data point [True]
# 22984 Text feature [y98h] present in test data point [True]
# 23089 Text feature [ordering] present in test data point [True]
# 24170 Text feature [thirdly] present in test data point [True]
# 24308 Text feature [pvhl30] present in test data point [True]
# 24356 Text feature [s12] present in test data point [True]
# 24374 Text feature [s15] present in test data point [True]
# 25921 Text feature [implicit] present in test data point [True]
# 26027 Text feature [downregulate] present in test data point [True]
# 26249 Text feature [s13] present in test data point [True]
# 26269 Text feature [tumourigenic] present in test data point [True]
# 26652 Text feature [polyubiquitination] present in test data point [True]
# 26719 Text feature [s17] present in test data point [True]
# 26919 Text feature [exemplary] present in test data point [True]
# 27103 Text feature [workflow] present in test data point [True]
# 27495 Text feature [inclusive] present in test data point [True]
# 28206 Text feature [prolyl] present in test data point [True]
# 28340 Text feature [r64p] present in test data point [True]
# 29278 Text feature [sdm] present in test data point [True]
# 29338 Text feature [035] present in test data point [True]
# 29400 Text feature [physicochemical] present in test data point [True]
# 29420 Text feature [outputs] present in test data point [True]
# 29670 Text feature [trees] present in test data point [True]
# 29828 Text feature [0043] present in test data point [True]
# 30381 Text feature [cam] present in test data point [True]
# 30475 Text feature [web] present in test data point [True]
# 30484 Text feature [writing] present in test data point [True]
# 30583 Text feature [classifier] present in test data point [True]
# 30786 Text feature [subgroups] present in test data point [True]
# 31585 Text feature [clinicopathological] present in test data point [True]
# 31835 Text feature [intolerant] present in test data point [True]
# 32277 Text feature [s16] present in test data point [True]
# 32343 Text feature [learning] present in test data point [True]
# 32344 Text feature [modelling] present in test data point [True]
# 32471 Text feature [exemplifying] present in test data point [True]
# 32474 Text feature [r167] present in test data point [True]
# 32614 Text feature [assisting] present in test data point [True]
# 33740 Text feature [training] present in test data point [True]
# 33741 Text feature [july] present in test data point [True]
# 33818 Text feature [phaeochromocytomas] present in test data point [True]
# 33839 Text feature [website] present in test data point [True]
# 33882 Text feature [polycythaemia] present in test data point [True]
# 34106 Text feature [395] present in test data point [True]
# 34403 Text feature [cullin] present in test data point [True]
# 34442 Text feature [s9b] present in test data point [True]
# 34520 Text feature [aims] present in test data point [True]
# 34938 Text feature [secondary] present in test data point [True]
# 35013 Text feature [minimally] present in test data point [True]
# 35137 Text feature [hydroxylated] present in test data point [True]
# 35147 Text feature [machine] present in test data point [True]
# 35164 Text feature [3p] present in test data point [True]
# 35544 Text feature [blind] present in test data point [True]
# 35693 Text feature [concept] present in test data point [True]
# 35698 Text feature [bap1] present in test data point [True]
# 35716 Text feature [hypoxia] present in test data point [True]
# 35726 Text feature [tumourigenesis] present in test data point [True]
# 36121 Text feature [subgroup] present in test data point [True]
# 36122 Text feature [endpoint] present in test data point [True]
# 36194 Text feature [replacements] present in test data point [True]
# 36302 Text feature [categorical] present in test data point [True]
# 36306 Text feature [umd] present in test data point [True]
# 36366 Text feature [797] present in test data point [True]
# 36422 Text feature [referenced] present in test data point [True]
# 36926 Text feature [descriptors] present in test data point [True]
# 36940 Text feature [never] present in test data point [True]
# 37001 Text feature [transgenic] present in test data point [True]
# 37121 Text feature [cns] present in test data point [True]
# 37164 Text feature [documenting] present in test data point [True]
# 37359 Text feature [gas] present in test data point [True]
# 37362 Text feature [definitely] present in test data point [True]
# 37368 Text feature [oncogene] present in test data point [True]
# 37684 Text feature [efficacy] present in test data point [True]
# 37698 Text feature [collated] present in test data point [True]
# 37701 Text feature [ubiquitination] present in test data point [True]
# 37780 Text feature [searchable] present in test data point [True]
# 37824 Text feature [entity] present in test data point [True]
# 38331 Text feature [m5] present in test data point [True]
# 38361 Text feature [204] present in test data point [True]
# 38382 Text feature [caveats] present in test data point [True]
# 38448 Text feature [potentials] present in test data point [True]
# 38538 Text feature [output] present in test data point [True]
# 38599 Text feature [permitted] present in test data point [True]
# 38605 Text feature [s9a] present in test data point [True]
# 38629 Text feature [s18] present in test data point [True]
# 38955 Text feature [preservation] present in test data point [True]
# 39011 Text feature [haemangioblastoma] present in test data point [True]
# 39046 Text feature [s11] present in test data point [True]
# 39053 Text feature [knock] present in test data point [True]
# 39074 Text feature [setd2] present in test data point [True]
# 39081 Text feature [regression] present in test data point [True]
# 39089 Text feature [drivers] present in test data point [True]
# 39346 Text feature [seventy] present in test data point [True]
# 39350 Text feature [432] present in test data point [True]
# 39438 Text feature [energy] present in test data point [True]
# 40469 Text feature [definitively] present in test data point [True]
# 40475 Text feature [cosmic] present in test data point [True]
# 40477 Text feature [syndromic] present in test data point [True]
# 40503 Text feature [hydroxyproline] present in test data point [True]
# 40598 Text feature [s9c] present in test data point [True]
# 40783 Text feature [ring] present in test data point [True]
# 40788 Text feature [spss] present in test data point [True]
# 40807 Text feature [eye] present in test data point [True]
# 41165 Text feature [pbrm1] present in test data point [True]
# 41166 Text feature [signatures] present in test data point [True]
# 41300 Text feature [subdivided] present in test data point [True]
# 41367 Text feature [node] present in test data point [True]
# 41420 Text feature [phaeochromocytoma] present in test data point [True]
# 41507 Text feature [demethylase] present in test data point [True]
# 41625 Text feature [trials] present in test data point [True]
# 41643 Text feature [pearson] present in test data point [True]
# 41757 Text feature [mb] present in test data point [True]
# 41796 Text feature [ternary] present in test data point [True]
# 42073 Text feature [train] present in test data point [True]
# 42418 Text feature [learn] present in test data point [True]
# 42581 Text feature [hif] present in test data point [True]
# 42619 Text feature [adapted] present in test data point [True]
# 42658 Text feature [reclassified] present in test data point [True]
# 42675 Text feature [tasks] present in test data point [True]
# 42743 Text feature [ligand] present in test data point [True]
# 42754 Text feature [y98n] present in test data point [True]
# 42798 Text feature [performance] present in test data point [True]
# 42802 Text feature [compound] present in test data point [True]
# 42857 Text feature [therapies] present in test data point [True]
# 42867 Text feature [classifications] present in test data point [True]
# 43001 Text feature [percent] present in test data point [True]
# 43003 Text feature [121] present in test data point [True]
# 43024 Text feature [impacts] present in test data point [True]
# 43354 Text feature [124] present in test data point [True]
# 43361 Text feature [2014] present in test data point [True]
# 43397 Text feature [s7] present in test data point [True]
# 43489 Text feature [paradoxically] present in test data point [True]
# 43588 Text feature [csps] present in test data point [True]
# 43591 Text feature [datasets] present in test data point [True]
# 43610 Text feature [incorrect] present in test data point [True]
# 44012 Text feature [performs] present in test data point [True]
# 44022 Text feature [computational] present in test data point [True]
# 44039 Text feature [bonding] present in test data point [True]
# 44059 Text feature [s8] present in test data point [True]
# 44400 Text feature [mutator] present in test data point [True]
# 44493 Text feature [subtype] present in test data point [True]
# 44499 Text feature [secondly] present in test data point [True]
# 44510 Text feature [csp] present in test data point [True]
# 44571 Text feature [iv] present in test data point [True]
# 44908 Text feature [concerted] present in test data point [True]
# 44930 Text feature [response] present in test data point [True]
# 44933 Text feature [predictor] present in test data point [True]
# 45006 Text feature [ligands] present in test data point [True]
# 45032 Text feature [ccrcc] present in test data point [True]
# 45064 Text feature [renal] present in test data point [True]
# 45144 Text feature [success] present in test data point [True]
# 45195 Text feature [limitation] present in test data point [True]
# 45211 Text feature [transparent] present in test data point [True]
# 45271 Text feature [canonical] present in test data point [True]
# 45272 Text feature [appearing] present in test data point [True]
# 45321 Text feature [173] present in test data point [True]
# 45331 Text feature [h115] present in test data point [True]
# 45372 Text feature [article] present in test data point [True]
# 45392 Text feature [353] present in test data point [True]
# 45626 Text feature [polybromo] present in test data point [True]
# 45697 Text feature [exon] present in test data point [True]
# 45699 Text feature [signature] present in test data point [True]
# 45700 Text feature [192] present in test data point [True]
# 45704 Text feature [ordered] present in test data point [True]
# 45814 Text feature [vi] present in test data point [True]
# 45843 Text feature [describes] present in test data point [True]
# 45859 Text feature [irrespective] present in test data point [True]
# 45940 Text feature [s10] present in test data point [True]
# 45951 Text feature [0014] present in test data point [True]
# 46016 Text feature [variables] present in test data point [True]
# 46039 Text feature [relates] present in test data point [True]
# 46061 Text feature [154] present in test data point [True]
# 46109 Text feature [isoform] present in test data point [True]
# 46225 Text feature [helical] present in test data point [True]
# 46326 Text feature [integrates] present in test data point [True]
# 46332 Text feature [pvhl] present in test data point [True]
# 46351 Text feature [inducible] present in test data point [True]
# 46359 Text feature [fifteen] present in test data point [True]
# 46372 Text feature [132] present in test data point [True]
# 46373 Text feature [clinically] present in test data point [True]
# 46426 Text feature [retinal] present in test data point [True]
# 46429 Text feature [kindreds] present in test data point [True]
# 46486 Text feature [adjustment] present in test data point [True]
# 46509 Text feature [tempting] present in test data point [True]
# 46527 Text feature [sorting] present in test data point [True]
# 46557 Text feature [poses] present in test data point [True]
# 46578 Text feature [binary] present in test data point [True]
# 46642 Text feature [iii] present in test data point [True]
# 46761 Text feature [biophysical] present in test data point [True]
# 46811 Text feature [predictive] present in test data point [True]
# 46820 Text feature [morbidity] present in test data point [True]
# 46823 Text feature [mortality] present in test data point [True]
# 46913 Text feature [homologues] present in test data point [True]
# 46964 Text feature [roughly] present in test data point [True]
# 47001 Text feature [sensitive] present in test data point [True]
# 47252 Text feature [ci] present in test data point [True]
# 47289 Text feature [nervous] present in test data point [True]
# 47313 Text feature [215] present in test data point [True]
# 47335 Text feature [122] present in test data point [True]
# 47348 Text feature [f119s] present in test data point [True]
# 47378 Text feature [alleles] present in test data point [True]
# 47522 Text feature [built] present in test data point [True]
# 47712 Text feature [associations] present in test data point [True]
# 47767 Text feature [differential] present in test data point [True]
# 47772 Text feature [elongin] present in test data point [True]
# 47840 Text feature [exploiting] present in test data point [True]
# 47871 Text feature [manifestation] present in test data point [True]
# 47874 Text feature [proteasomal] present in test data point [True]
# 47940 Text feature [forest] present in test data point [True]
# 47955 Text feature [assessing] present in test data point [True]
# 47987 Text feature [brca1] present in test data point [True]
# 47990 Text feature [explains] present in test data point [True]
# 48046 Text feature [lie] present in test data point [True]
# 48111 Text feature [cutoff] present in test data point [True]
# 48113 Text feature [193] present in test data point [True]
# 48133 Text feature [applications] present in test data point [True]
# 48135 Text feature [looked] present in test data point [True]
# 48137 Text feature [lindau] present in test data point [True]
# 48273 Text feature [improved] present in test data point [True]
# 48276 Text feature [delineate] present in test data point [True]
# 48279 Text feature [compiled] present in test data point [True]
# 48280 Text feature [hippel] present in test data point [True]
# 48401 Text feature [none] present in test data point [True]
# 48403 Text feature [passenger] present in test data point [True]
# 48414 Text feature [application] present in test data point [True]
# 48432 Text feature [accessed] present in test data point [True]
# 48442 Text feature [combination] present in test data point [True]
# 48452 Text feature [kdm6a] present in test data point [True]
# 48557 Text feature [receptor] present in test data point [True]
# 48569 Text feature [strategies] present in test data point [True]
# 48597 Text feature [evolutionary] present in test data point [True]
# 48607 Text feature [0001] present in test data point [True]
# 48617 Text feature [accounting] present in test data point [True]
# 48620 Text feature [achieve] present in test data point [True]
# 48625 Text feature [scanning] present in test data point [True]
# 48628 Text feature [162] present in test data point [True]
# 48631 Text feature [bioinformatics] present in test data point [True]
# 48646 Text feature [tolerated] present in test data point [True]
# 48659 Text feature [broadly] present in test data point [True]
# 48665 Text feature [whereby] present in test data point [True]
# 48808 Text feature [articles] present in test data point [True]
# 48889 Text feature [resource] present in test data point [True]
# 48890 Text feature [conformation] present in test data point [True]
# 48908 Text feature [free] present in test data point [True]
# 48921 Text feature [wall] present in test data point [True]
# 48932 Text feature [250] present in test data point [True]
# 48938 Text feature [partners] present in test data point [True]
# 48946 Text feature [fashion] present in test data point [True]
# 48968 Text feature [disparate] present in test data point [True]
# 48974 Text feature [patients] present in test data point [True]
# 48981 Text feature [fourteen] present in test data point [True]
# 48992 Text feature [drive] present in test data point [True]
# 48995 Text feature [ac] present in test data point [True]
# 49006 Text feature [optimized] present in test data point [True]
# 49009 Text feature [tumours] present in test data point [True]
# 49178 Text feature [relate] present in test data point [True]
# 49234 Text feature [congenital] present in test data point [True]
# 49258 Text feature [prognosis] present in test data point [True]
# 49304 Text feature [experimentally] present in test data point [True]
# 49308 Text feature [partial] present in test data point [True]
# 49312 Text feature [methylation] present in test data point [True]
# 49316 Text feature [differently] present in test data point [True]
# 49319 Text feature [primary] present in test data point [True]
# 49326 Text feature [comes] present in test data point [True]
# 49412 Text feature [graph] present in test data point [True]
# 49539 Text feature [better] present in test data point [True]
# 49586 Text feature [correlations] present in test data point [True]
# 49641 Text feature [silico] present in test data point [True]
# 49642 Text feature [shed] present in test data point [True]
# 49659 Text feature [genotype] present in test data point [True]
# 49661 Text feature [driver] present in test data point [True]
# 49674 Text feature [classify] present in test data point [True]
# 49688 Text feature [heterogeneity] present in test data point [True]
# 49697 Text feature [61] present in test data point [True]
# 49726 Text feature [electrostatic] present in test data point [True]
# 49739 Text feature [conflicting] present in test data point [True]
# 49746 Text feature [combine] present in test data point [True]
# 49779 Text feature [settings] present in test data point [True]
# 49805 Text feature [improve] present in test data point [True]
# 49836 Text feature [models] present in test data point [True]
# 49842 Text feature [186] present in test data point [True]
# 49899 Text feature [move] present in test data point [True]
# 49900 Text feature [vhl] present in test data point [True]
# 49902 Text feature [von] present in test data point [True]
# 49912 Text feature [tolerant] present in test data point [True]
# 49930 Text feature [destabilization] present in test data point [True]
# 49954 Text feature [express] present in test data point [True]
# 49956 Text feature [seventeen] present in test data point [True]
# 49959 Text feature [versus] present in test data point [True]
# 50214 Text feature [s6] present in test data point [True]
# 50218 Text feature [methodology] present in test data point [True]
# 50389 Text feature [highlighting] present in test data point [True]
# 50408 Text feature [incompletely] present in test data point [True]
# 50417 Text feature [112] present in test data point [True]
# 50419 Text feature [s5] present in test data point [True]
# 50433 Text feature [situations] present in test data point [True]
# 50444 Text feature [biallelic] present in test data point [True]
# 50474 Text feature [affinities] present in test data point [True]
# 50475 Text feature [emphasize] present in test data point [True]
# 50492 Text feature [literature] present in test data point [True]
# 50494 Text feature [management] present in test data point [True]
# 50537 Text feature [standardized] present in test data point [True]
# 50615 Text feature [enabled] present in test data point [True]
# 50620 Text feature [robust] present in test data point [True]
# 50623 Text feature [sided] present in test data point [True]
# 50635 Text feature [classification] present in test data point [True]
# 50637 Text feature [multi] present in test data point [True]
# 50638 Text feature [original] present in test data point [True]
# 50693 Text feature [stabilization] present in test data point [True]
# 50695 Text feature [kind] present in test data point [True]
# 50730 Text feature [manifestations] present in test data point [True]
# 50741 Text feature [degradation] present in test data point [True]
# 50746 Text feature [universal] present in test data point [True]
# 50751 Text feature [67] present in test data point [True]
# 50754 Text feature [intermolecular] present in test data point [True]
# 50775 Text feature [fifty] present in test data point [True]
# 50784 Text feature [limitations] present in test data point [True]
# 50793 Text feature [debated] present in test data point [True]
# 50803 Text feature [environment] present in test data point [True]
# 50818 Text feature [comprised] present in test data point [True]
# 50837 Text feature [generation] present in test data point [True]
# 50843 Text feature [254] present in test data point [True]
# 50854 Text feature [alongside] present in test data point [True]
# 50874 Text feature [extended] present in test data point [True]
# 50899 Text feature [looking] present in test data point [True]
# 50907 Text feature [aim] present in test data point [True]
# 50956 Text feature [depth] present in test data point [True]
# 50970 Text feature [named] present in test data point [True]
# 50990 Text feature [freely] present in test data point [True]
# 50993 Text feature [targeted] present in test data point [True]
# 51023 Text feature [relies] present in test data point [True]
# 51027 Text feature [numerous] present in test data point [True]
# 51041 Text feature [diseases] present in test data point [True]
# 51042 Text feature [unpaired] present in test data point [True]
# 51239 Text feature [92] present in test data point [True]
# 51245 Text feature [challenges] present in test data point [True]
# 51257 Text feature [dataset] present in test data point [True]
# 51265 Text feature [accuracy] present in test data point [True]
# 51281 Text feature [paradigms] present in test data point [True]
# 51285 Text feature [clinical] present in test data point [True]
# 51295 Text feature [probable] present in test data point [True]
# 51296 Text feature [recessive] present in test data point [True]
# 51326 Text feature [substituted] present in test data point [True]
# 51353 Text feature [accurate] present in test data point [True]
# 51363 Text feature [91] present in test data point [True]
# 51382 Text feature [sources] present in test data point [True]
# 51398 Text feature [suggestion] present in test data point [True]
# 51420 Text feature [implying] present in test data point [True]
# 51421 Text feature [functionality] present in test data point [True]
# 51429 Text feature [promoter] present in test data point [True]
# 51439 Text feature [294] present in test data point [True]
# 51468 Text feature [disordered] present in test data point [True]
# 51488 Text feature [server] present in test data point [True]
# 51490 Text feature [tumour] present in test data point [True]
# 51493 Text feature [56] present in test data point [True]
# 51524 Text feature [dysregulation] present in test data point [True]
# 51536 Text feature [categories] present in test data point [True]
# 51547 Text feature [dysfunction] present in test data point [True]
# 51553 Text feature [consider] present in test data point [True]
# 51558 Text feature [inter] present in test data point [True]
# 51561 Text feature [research] present in test data point [True]
# 51582 Text feature [utilized] present in test data point [True]
# 51597 Text feature [good] present in test data point [True]
# 51599 Text feature [documented] present in test data point [True]
# 51610 Text feature [highlight] present in test data point [True]
# 51612 Text feature [factor] present in test data point [True]
# 51622 Text feature [statement] present in test data point [True]
# 51625 Text feature [350] present in test data point [True]
# 51632 Text feature [status] present in test data point [True]
# 51664 Text feature [php] present in test data point [True]
# 51692 Text feature [90] present in test data point [True]
# 51716 Text feature [worldwide] present in test data point [True]
# 51724 Text feature [scheme] present in test data point [True]
# 51729 Text feature [opportunity] present in test data point [True]
# 51732 Text feature [58] present in test data point [True]
# 51735 Text feature [51] present in test data point [True]
# 51751 Text feature [constructed] present in test data point [True]
# 51752 Text feature [62] present in test data point [True]
# 51761 Text feature [implementation] present in test data point [True]
# 51762 Text feature [19] present in test data point [True]
# 51778 Text feature [designated] present in test data point [True]
# 51786 Text feature [influenced] present in test data point [True]
# 51790 Text feature [thermodynamic] present in test data point [True]
# 51791 Text feature [respect] present in test data point [True]
# 51797 Text feature [s2a] present in test data point [True]
# 51801 Text feature [155] present in test data point [True]
# 51811 Text feature [initially] present in test data point [True]
# 51813 Text feature [material] present in test data point [True]
# 51830 Text feature [excellent] present in test data point [True]
# 51835 Text feature [validate] present in test data point [True]
# 51886 Text feature [inclusion] present in test data point [True]
# 51895 Text feature [random] present in test data point [True]
# 51899 Text feature [wt] present in test data point [True]
# 51901 Text feature [date] present in test data point [True]
# 51906 Text feature [analysed] present in test data point [True]
# 51910 Text feature [sensitivity] present in test data point [True]
# 51919 Text feature [patient] present in test data point [True]
# 51920 Text feature [conservation] present in test data point [True]
# 51925 Text feature [history] present in test data point [True]
# 51927 Text feature [naturally] present in test data point [True]
# 51931 Text feature [s4] present in test data point [True]
# 51943 Text feature [subunit] present in test data point [True]
# 51953 Text feature [pathogenesis] present in test data point [True]
# 51954 Text feature [rarely] present in test data point [True]
# 51956 Text feature [213] present in test data point [True]
# 51959 Text feature [rare] present in test data point [True]
# 51961 Text feature [21] present in test data point [True]
# 51970 Text feature [20] present in test data point [True]
# 52133 Text feature [ranged] present in test data point [True]
# 52135 Text feature [unusual] present in test data point [True]
# 52156 Text feature [counts] present in test data point [True]
# 52160 Text feature [severe] present in test data point [True]
# 52166 Text feature [lysine] present in test data point [True]
# 52183 Text feature [cohorts] present in test data point [True]
# 52190 Text feature [predicting] present in test data point [True]
# 52203 Text feature [modifiers] present in test data point [True]
# 52209 Text feature [seem] present in test data point [True]
# 52216 Text feature [11] present in test data point [True]
# 52312 Text feature [95] present in test data point [True]
# 52314 Text feature [57] present in test data point [True]
# 52315 Text feature [demonstrates] present in test data point [True]
# 52322 Text feature [easily] present in test data point [True]
# 52351 Text feature [publically] present in test data point [True]
# 52352 Text feature [matrix] present in test data point [True]
# 52356 Text feature [successfully] present in test data point [True]
# 52375 Text feature [reports] present in test data point [True]
# 52376 Text feature [regarding] present in test data point [True]
# 52377 Text feature [namely] present in test data point [True]
# 52389 Text feature [1000] present in test data point [True]
# 52393 Text feature [gradient] present in test data point [True]
# 52398 Text feature [impairment] present in test data point [True]
# 52403 Text feature [created] present in test data point [True]
# 52407 Text feature [linear] present in test data point [True]
# 52408 Text feature [presents] present in test data point [True]
# 52416 Text feature [student] present in test data point [True]
# 52451 Text feature [ii] present in test data point [True]
# 52453 Text feature [64] present in test data point [True]
# 52474 Text feature [substitutions] present in test data point [True]
# 52486 Text feature [rules] present in test data point [True]
# 52491 Text feature [review] present in test data point [True]
# 52497 Text feature [eleven] present in test data point [True]
# 52501 Text feature [representative] present in test data point [True]
# 52509 Text feature [incomplete] present in test data point [True]
# 52512 Text feature [time] present in test data point [True]
# 52518 Text feature [52] present in test data point [True]
# 52554 Text feature [statistics] present in test data point [True]
# 52571 Text feature [84] present in test data point [True]
# 52572 Text feature [59] present in test data point [True]
# 52574 Text feature [disease] present in test data point [True]
# 52577 Text feature [finer] present in test data point [True]
# 52593 Text feature [destabilizing] present in test data point [True]
# 52594 Text feature [category] present in test data point [True]
# 52595 Text feature [81] present in test data point [True]
# 52597 Text feature [underlies] present in test data point [True]
# 52601 Text feature [dramatically] present in test data point [True]
# 52603 Text feature [98] present in test data point [True]
# 52608 Text feature [defective] present in test data point [True]
# 52621 Text feature [76] present in test data point [True]
# 52632 Text feature [box] present in test data point [True]
# 52633 Text feature [s3] present in test data point [True]
# 52644 Text feature [syndrome] present in test data point [True]
# 52646 Text feature [tend] present in test data point [True]
# 52662 Text feature [assembly] present in test data point [True]
# 52663 Text feature [82] present in test data point [True]
# 52676 Text feature [unknown] present in test data point [True]
# 52681 Text feature [moderate] present in test data point [True]
# 52682 Text feature [inheritance] present in test data point [True]
# 52689 Text feature [combining] present in test data point [True]
# 52697 Text feature [list] present in test data point [True]
# 52702 Text feature [related] present in test data point [True]
# 52707 Text feature [structures] present in test data point [True]
# 52714 Text feature [uses] present in test data point [True]
# 52715 Text feature [discriminate] present in test data point [True]
# 52718 Text feature [63] present in test data point [True]
# 52725 Text feature [substitution] present in test data point [True]
# 52728 Text feature [summarized] present in test data point [True]
# 52737 Text feature [sets] present in test data point [True]
# 52745 Text feature [93] present in test data point [True]
# 52750 Text feature [balance] present in test data point [True]
# 52752 Text feature [usually] present in test data point [True]
# 52755 Text feature [comprehensive] present in test data point [True]
# 52760 Text feature [minor] present in test data point [True]
# 52763 Text feature [18] present in test data point [True]
# 52768 Text feature [factors] present in test data point [True]
# 52777 Text feature [targets] present in test data point [True]
# 52779 Text feature [increases] present in test data point [True]
# 52781 Text feature [solvent] present in test data point [True]
# 52787 Text feature [correlate] present in test data point [True]
# 52797 Text feature [linking] present in test data point [True]
# 52798 Text feature [66] present in test data point [True]
# 52799 Text feature [758] present in test data point [True]
# 52801 Text feature [s2] present in test data point [True]
# 52804 Text feature [fisher] present in test data point [True]
# 52806 Text feature [explaining] present in test data point [True]
# 52812 Text feature [annotated] present in test data point [True]
# 52814 Text feature [properties] present in test data point [True]
# 52820 Text feature [tree] present in test data point [True]
# 52821 Text feature [seems] present in test data point [True]
# 52826 Text feature [alterations] present in test data point [True]
# 52835 Text feature [examples] present in test data point [True]
# 52839 Text feature [s2c] present in test data point [True]
# 52840 Text feature [suppression] present in test data point [True]
# 52845 Text feature [affinity] present in test data point [True]
# 52850 Text feature [exhibits] present in test data point [True]
# 52851 Text feature [databases] present in test data point [True]
# 52864 Text feature [group] present in test data point [True]
# 52865 Text feature [independently] present in test data point [True]
# 52868 Text feature [speculate] present in test data point [True]
# 52876 Text feature [light] present in test data point [True]
# 52888 Text feature [unless] present in test data point [True]
# 52896 Text feature [purpose] present in test data point [True]
# 52900 Text feature [phenotypic] present in test data point [True]
# 52904 Text feature [mechanisms] present in test data point [True]
# 52912 Text feature [portion] present in test data point [True]
# 52916 Text feature [systems] present in test data point [True]
# 52922 Text feature [sporadic] present in test data point [True]
# 52923 Text feature [commonly] present in test data point [True]
# 52926 Text feature [along] present in test data point [True]
# 52929 Text feature [simply] present in test data point [True]
# 52932 Text feature [produce] present in test data point [True]
# 52935 Text feature [supports] present in test data point [True]
# 52940 Text feature [allelic] present in test data point [True]
# 52948 Text feature [900] present in test data point [True]
# 52949 Text feature [cohort] present in test data point [True]
# 52951 Text feature [60] present in test data point [True]
# 52954 Text feature [structurally] present in test data point [True]
# 52956 Text feature [supporting] present in test data point [True]
# 52968 Text feature [chromosome] present in test data point [True]
# 52969 Text feature [figures] present in test data point [True]
# 52971 Text feature [tools] present in test data point [True]
# 52977 Text feature [explain] present in test data point [True]
# 52981 Text feature [phenotypes] present in test data point [True]
# 52983 Text feature [14] present in test data point [True]
# 52984 Text feature [point] present in test data point [True]
# 52985 Text feature [combined] present in test data point [True]
# 52994 Text feature [carcinoma] present in test data point [True]
# 52998 Text feature [tissues] present in test data point [True]
# 53005 Text feature [earlier] present in test data point [True]
# 53008 Text feature [s2b] present in test data point [True]
# 53013 Text feature [69] present in test data point [True]
# 53014 Text feature [certain] present in test data point [True]
# 53018 Text feature [presented] present in test data point [True]
# 53026 Text feature [tables] present in test data point [True]
# 53029 Text feature [solely] present in test data point [True]
# 53033 Text feature [diagnosis] present in test data point [True]
# 53037 Text feature [uk] present in test data point [True]
# 53050 Text feature [exposure] present in test data point [True]
# 53052 Text feature [experimental] present in test data point [True]
# 53062 Text feature [nucleotide] present in test data point [True]
# 53063 Text feature [68] present in test data point [True]
# 53067 Text feature [strategy] present in test data point [True]
# 53078 Text feature [sift] present in test data point [True]
# 53082 Text feature [culture] present in test data point [True]
# 53085 Text feature [reviewed] present in test data point [True]
# 53100 Text feature [quality] present in test data point [True]
# 53104 Text feature [13] present in test data point [True]
# 53126 Text feature [challenging] present in test data point [True]
# 53132 Text feature [facilitated] present in test data point [True]
# 53140 Text feature [polymorphisms] present in test data point [True]
# 53143 Text feature [description] present in test data point [True]
# 53156 Text feature [short] present in test data point [True]
# 53157 Text feature [conclusions] present in test data point [True]
# 53160 Text feature [stable] present in test data point [True]
# 53163 Text feature [alone] present in test data point [True]
# 53169 Text feature [quantitatively] present in test data point [True]
# 53177 Text feature [biochemical] present in test data point [True]
# 53181 Text feature [lines] present in test data point [True]
# 53185 Text feature [reflected] present in test data point [True]
# 53186 Text feature [retain] present in test data point [True]
# 53189 Text feature [com] present in test data point [True]
# 53191 Text feature [prevalence] present in test data point [True]
# 53192 Text feature [17] present in test data point [True]
# 53197 Text feature [approaches] present in test data point [True]
# 53200 Text feature [predominantly] present in test data point [True]
# 53201 Text feature [features] present in test data point [True]
# 53209 Text feature [extremely] present in test data point [True]
# 53213 Text feature [subsequent] present in test data point [True]
# 53214 Text feature [regulate] present in test data point [True]
# 53215 Text feature [mutants] present in test data point [True]
# 53223 Text feature [require] present in test data point [True]
# 53225 Text feature [determining] present in test data point [True]
# 53226 Text feature [hydrogen] present in test data point [True]
# 53233 Text feature [pathogenic] present in test data point [True]
# 53237 Text feature [developing] present in test data point [True]
# 53241 Text feature [representing] present in test data point [True]
# 53242 Text feature [needed] present in test data point [True]
# 53247 Text feature [summary] present in test data point [True]
# 53250 Text feature [47] present in test data point [True]
# 53254 Text feature [notable] present in test data point [True]
# 53266 Text feature [subtle] present in test data point [True]
# 53277 Text feature [link] present in test data point [True]
# 53280 Text feature [target] present in test data point [True]
# 53285 Text feature [buried] present in test data point [True]
# 53292 Text feature [prevent] present in test data point [True]
# 53293 Text feature [distributed] present in test data point [True]
# 53296 Text feature [ncbi] present in test data point [True]
# 53298 Text feature [closely] present in test data point [True]
# 53305 Text feature [listed] present in test data point [True]
# 53312 Text feature [clear] present in test data point [True]
# 53313 Text feature [describe] present in test data point [True]
# 53322 Text feature [crystal] present in test data point [True]
# 53329 Text feature [originally] present in test data point [True]
# 53331 Text feature [difference] present in test data point [True]
# 53332 Text feature [48] present in test data point [True]
# 53337 Text feature [values] present in test data point [True]
# 53342 Text feature [overall] present in test data point [True]
# 53362 Text feature [apparently] present in test data point [True]
# 53363 Text feature [developed] present in test data point [True]
# 53366 Text feature [integrated] present in test data point [True]
# 53367 Text feature [diverse] present in test data point [True]
# 53370 Text feature [mechanism] present in test data point [True]
# 53372 Text feature [influence] present in test data point [True]
# 53379 Text feature [coefficient] present in test data point [True]
# 53389 Text feature [exact] present in test data point [True]
# 53400 Text feature [information] present in test data point [True]
# 53405 Text feature [75] present in test data point [True]
# 53408 Text feature [seen] present in test data point [True]
# 53410 Text feature [mainly] present in test data point [True]
# 53417 Text feature [generic] present in test data point [True]
# 53421 Text feature [6a] present in test data point [True]
# 53422 Text feature [use] present in test data point [True]
# 53423 Text feature [develop] present in test data point [True]
# 53424 Text feature [whole] present in test data point [True]
# 53425 Text feature [mouse] present in test data point [True]
# 53436 Text feature [independent] present in test data point [True]
# 53438 Text feature [development] present in test data point [True]
# 53447 Text feature [terms] present in test data point [True]
# 53448 Text feature [greater] present in test data point [True]
# 53453 Text feature [49] present in test data point [True]
# 53459 Text feature [typical] present in test data point [True]
# 53460 Text feature [knowledge] present in test data point [True]
# 53471 Text feature [hundred] present in test data point [True]
# 53476 Text feature [non] present in test data point [True]
# 53477 Text feature [chain] present in test data point [True]
# 53478 Text feature [65] present in test data point [True]
# 53482 Text feature [54] present in test data point [True]
# 53486 Text feature [elucidate] present in test data point [True]
# 53487 Text feature [predictions] present in test data point [True]
# 53488 Text feature [70] present in test data point [True]
# 53491 Text feature [thereby] present in test data point [True]
# 53496 Text feature [interface] present in test data point [True]
# 53501 Text feature [reference] present in test data point [True]
# 53503 Text feature [assessment] present in test data point [True]
# 53510 Text feature [classified] present in test data point [True]
# 53515 Text feature [report] present in test data point [True]
# 53519 Text feature [us] present in test data point [True]
# 53525 Text feature [39] present in test data point [True]
# 53530 Text feature [predict] present in test data point [True]
# 53532 Text feature [variety] present in test data point [True]
# 53536 Text feature [occurs] present in test data point [True]
# 53538 Text feature [act] present in test data point [True]
# 53539 Text feature [insufficient] present in test data point [True]
# 53540 Text feature [12] present in test data point [True]
# 53545 Text feature [investigated] present in test data point [True]
# 53546 Text feature [regulation] present in test data point [True]
# 53551 Text feature [al] present in test data point [True]
# 53553 Text feature [agreement] present in test data point [True]
# 53557 Text feature [destabilize] present in test data point [True]
# 53558 Text feature [work] present in test data point [True]
# 53559 Text feature [reflect] present in test data point [True]
# 53561 Text feature [demonstrated] present in test data point [True]
# 53562 Text feature [details] present in test data point [True]
# 53564 Text feature [matched] present in test data point [True]
# 53565 Text feature [depending] present in test data point [True]
# 53566 Text feature [proportion] present in test data point [True]
# 53567 Text feature [supported] present in test data point [True]
# 53575 Text feature [often] present in test data point [True]
# 53579 Text feature [consensus] present in test data point [True]
# 53580 Text feature [normally] present in test data point [True]
# 53583 Text feature [variants] present in test data point [True]
# 53584 Text feature [able] present in test data point [True]
# 53585 Text feature [allow] present in test data point [True]
# 53588 Text feature [activity] present in test data point [True]
# 53590 Text feature [et] present in test data point [True]
# 53591 Text feature [contacts] present in test data point [True]
# 53596 Text feature [relationship] present in test data point [True]
# 53599 Text feature [complementary] present in test data point [True]
# 53603 Text feature [though] present in test data point [True]
# 53604 Text feature [folding] present in test data point [True]
# 53605 Text feature [future] present in test data point [True]
# 53614 Text feature [exclusively] present in test data point [True]
# 53617 Text feature [without] present in test data point [True]
# 53621 Text feature [72] present in test data point [True]
# 53622 Text feature [potentially] present in test data point [True]
# 53625 Text feature [exhibit] present in test data point [True]
# 53629 Text feature [product] present in test data point [True]
# 53637 Text feature [mutated] present in test data point [True]
# 53639 Text feature [direct] present in test data point [True]
# 53644 Text feature [lead] present in test data point [True]
# 53646 Text feature [common] present in test data point [True]
# 53647 Text feature [account] present in test data point [True]
# 53651 Text feature [2b] present in test data point [True]
# 53654 Text feature [location] present in test data point [True]
# 53655 Text feature [long] present in test data point [True]
# 53656 Text feature [frequently] present in test data point [True]
# 53658 Text feature [autosomal] present in test data point [True]
# 53660 Text feature [deletions] present in test data point [True]
# 53661 Text feature [residue] present in test data point [True]
# 53668 Text feature [correlation] present in test data point [True]
# 53670 Text feature [55] present in test data point [True]
# 53672 Text feature [number] present in test data point [True]
# 53678 Text feature [deleted] present in test data point [True]
# 53679 Text feature [throughout] present in test data point [True]
# 53687 Text feature [somatic] present in test data point [True]
# 53694 Text feature [explanation] present in test data point [True]
# 53700 Text feature [study] present in test data point [True]
# 53703 Text feature [sheet] present in test data point [True]
# 53705 Text feature [called] present in test data point [True]
# 53706 Text feature [statistical] present in test data point [True]
# 53707 Text feature [small] present in test data point [True]
# 53713 Text feature [generate] present in test data point [True]
# 53715 Text feature [consisting] present in test data point [True]
# 53716 Text feature [last] present in test data point [True]
# 53723 Text feature [risk] present in test data point [True]
# 53727 Text feature [43] present in test data point [True]
# 53730 Text feature [included] present in test data point [True]
# 53733 Text feature [confirm] present in test data point [True]
# 53734 Text feature [33] present in test data point [True]
# 53735 Text feature [supplementary] present in test data point [True]
# 53738 Text feature [molecular] present in test data point [True]
# 53739 Text feature [basis] present in test data point [True]
# 53741 Text feature [enough] present in test data point [True]
# 53742 Text feature [2a] present in test data point [True]
# 53743 Text feature [final] present in test data point [True]
# 53745 Text feature [comparisons] present in test data point [True]
# 53750 Text feature [across] present in test data point [True]
# 53755 Text feature [prediction] present in test data point [True]
# 53758 Text feature [80] present in test data point [True]
# 53761 Text feature [interfaces] present in test data point [True]
# 53763 Text feature [association] present in test data point [True]
# 53770 Text feature [conditions] present in test data point [True]
# 53771 Text feature [familial] present in test data point [True]
# 53772 Text feature [potential] present in test data point [True]
# 53776 Text feature [various] present in test data point [True]
# 53780 Text feature [higher] present in test data point [True]
# 53783 Text feature [useful] present in test data point [True]
# 53785 Text feature [biological] present in test data point [True]
# 53786 Text feature [impair] present in test data point [True]
# ...
# 53924 Text feature [germline] present in test data point [True]
# 53925 Text feature [disrupted] present in test data point [True]
# 53927 Text feature [latter] present in test data point [True]
# 53932 Text feature [hereditary] present in test data point [True]
# 53933 Text feature [variability] present in test data point [True]
# 53934 Text feature [distinct] present in test data point [True]
# 53938 Text feature [analyses] present in test data point [True]
# 53939 Text feature [appear] present in test data point [True]
# 53942 Text feature [45] present in test data point [True]
# 53944 Text feature [hydrophobic] present in test data point [True]
# 53945 Text feature [29] present in test data point [True]
# 53947 Text feature [database] present in test data point [True]
# 53949 Text feature [include] present in test data point [True]
# 53950 Text feature [38] present in test data point [True]
# 53953 Text feature [first] present in test data point [True]
# 53954 Text feature [support] present in test data point [True]
# 53956 Text feature [dependent] present in test data point [True]
# 53957 Text feature [degree] present in test data point [True]
# 53959 Text feature [necessary] present in test data point [True]
# 53963 Text feature [directed] present in test data point [True]
# 53964 Text feature [types] present in test data point [True]
# 53967 Text feature [side] present in test data point [True]
# 53972 Text feature [44] present in test data point [True]
# 53973 Text feature [94] present in test data point [True]
# 53974 Text feature [less] present in test data point [True]
# 53975 Text feature [generated] present in test data point [True]
# 53978 Text feature [particularly] present in test data point [True]
# 53981 Text feature [position] present in test data point [True]
# 53982 Text feature [involve] present in test data point [True]
# 53985 Text feature [complexes] present in test data point [True]
# 53986 Text feature [quantitative] present in test data point [True]
# 53987 Text feature [novel] present in test data point [True]
# 53988 Text feature [cell] present in test data point [True]
# 53992 Text feature [truncating] present in test data point [True]
# 53993 Text feature [approach] present in test data point [True]
# 54002 Text feature [mutations] present in test data point [True]
# 54004 Text feature [presence] present in test data point [True]
# 54006 Text feature [forms] present in test data point [True]
# 54007 Text feature [23] present in test data point [True]
# 54008 Text feature [sequencing] present in test data point [True]
# 54009 Text feature [interfere] present in test data point [True]
# 54010 Text feature [suppressor] present in test data point [True]
# 54012 Text feature [28] present in test data point [True]
# 54014 Text feature [disruption] present in test data point [True]
# 54015 Text feature [made] present in test data point [True]
# 54016 Text feature [100] present in test data point [True]
# 54019 Text feature [families] present in test data point [True]
# 54020 Text feature [27] present in test data point [True]
# 54025 Text feature [34] present in test data point [True]
# 54027 Text feature [since] present in test data point [True]
# 54030 Text feature [major] present in test data point [True]
# 54033 Text feature [materials] present in test data point [True]
# 54034 Text feature [observation] present in test data point [True]
# 54035 Text feature [test] present in test data point [True]
# 54038 Text feature [low] present in test data point [True]
# 54040 Text feature [resulted] present in test data point [True]
# 54041 Text feature [reported] present in test data point [True]
# 54043 Text feature [underlying] present in test data point [True]
# 54044 Text feature [observations] present in test data point [True]
# 54045 Text feature [extent] present in test data point [True]
# 54049 Text feature [functional] present in test data point [True]
# 54050 Text feature [affects] present in test data point [True]
# 54053 Text feature [finally] present in test data point [True]
# 54054 Text feature [considered] present in test data point [True]
# 54056 Text feature [new] present in test data point [True]
# 54059 Text feature [detected] present in test data point [True]
# 54062 Text feature [22] present in test data point [True]
# 54063 Text feature [multiple] present in test data point [True]
# 54064 Text feature [definition] present in test data point [True]
# 54065 Text feature [hypothesis] present in test data point [True]
# 54071 Text feature [inactivation] present in test data point [True]
# 54072 Text feature [www] present in test data point [True]
# 54076 Text feature [sufficient] present in test data point [True]
# 54080 Text feature [upon] present in test data point [True]
# 54082 Text feature [proposed] present in test data point [True]
# 54085 Text feature [system] present in test data point [True]
# 54086 Text feature [identification] present in test data point [True]
# 54091 Text feature [excluded] present in test data point [True]
# 54092 Text feature [part] present in test data point [True]
# 54094 Text feature [finding] present in test data point [True]
# 54095 Text feature [obtained] present in test data point [True]
# 54096 Text feature [single] present in test data point [True]
# 54098 Text feature [limited] present in test data point [True]
# 54099 Text feature [exposed] present in test data point [True]
# 54100 Text feature [24] present in test data point [True]
# 54101 Text feature [clearly] present in test data point [True]
# 54105 Text feature [interactions] present in test data point [True]
# 54109 Text feature [derived] present in test data point [True]
# 54111 Text feature [characterized] present in test data point [True]
# 54112 Text feature [nearly] present in test data point [True]
# 54113 Text feature [might] present in test data point [True]
# 54114 Text feature [phenotype] present in test data point [True]
# 54115 Text feature [represent] present in test data point [True]
# 54116 Text feature [general] present in test data point [True]
# 54117 Text feature [effects] present in test data point [True]
# 54118 Text feature [assess] present in test data point [True]
# 54125 Text feature [40] present in test data point [True]
# 54127 Text feature [site] present in test data point [True]
# 54128 Text feature [expression] present in test data point [True]
# 54130 Text feature [32] present in test data point [True]
# 54132 Text feature [normal] present in test data point [True]
# 54133 Text feature [methods] present in test data point [True]
# 54136 Text feature [stability] present in test data point [True]
# 54137 Text feature [mutation] present in test data point [True]
# 54138 Text feature [10] present in test data point [True]
# 54139 Text feature [according] present in test data point [True]
# 54141 Text feature [disrupt] present in test data point [True]
# 54144 Text feature [resulting] present in test data point [True]
# 54145 Text feature [level] present in test data point [True]
# 54146 Text feature [50] present in test data point [True]
# 54149 Text feature [seven] present in test data point [True]
# 54154 Text feature [25] present in test data point [True]
# 54157 Text feature [studies] present in test data point [True]
# 54162 Text feature [15] present in test data point [True]
# 54164 Text feature [missense] present in test data point [True]
# 54165 Text feature [defined] present in test data point [True]
# 54166 Text feature [introduction] present in test data point [True]
# 54168 Text feature [family] present in test data point [True]
# 54169 Text feature [findings] present in test data point [True]
# 54170 Text feature [available] present in test data point [True]
# 54171 Text feature [algorithm] present in test data point [True]
# 54176 Text feature [cause] present in test data point [True]
# 54178 Text feature [suggest] present in test data point [True]
# 54180 Text feature [frameshift] present in test data point [True]
# 54181 Text feature [associated] present in test data point [True]
# 54182 Text feature [rather] present in test data point [True]
# 54183 Text feature [another] present in test data point [True]
# 54185 Text feature [entire] present in test data point [True]
# 54186 Text feature [domain] present in test data point [True]
# 54187 Text feature [suggests] present in test data point [True]
# 54188 Text feature [would] present in test data point [True]
# 54191 Text feature [formation] present in test data point [True]
# 54192 Text feature [evidence] present in test data point [True]
# 54194 Text feature [yet] present in test data point [True]
# 54195 Text feature [lack] present in test data point [True]
# 54196 Text feature [16] present in test data point [True]
# 54200 Text feature [fig] present in test data point [True]
# 54203 Text feature [furthermore] present in test data point [True]
# 54204 Text feature [42] present in test data point [True]
# 54207 Text feature [core] present in test data point [True]
# 54208 Text feature [provided] present in test data point [True]
# 54209 Text feature [interacts] present in test data point [True]
# 54211 Text feature [residues] present in test data point [True]
# 54212 Text feature [found] present in test data point [True]
# 54213 Text feature [although] present in test data point [True]
# 54214 Text feature [compared] present in test data point [True]
# 54216 Text feature [set] present in test data point [True]
# 54217 Text feature [due] present in test data point [True]
# 54218 Text feature [30] present in test data point [True]
# 54219 Text feature [equal] present in test data point [True]
# 54220 Text feature [suggesting] present in test data point [True]
# 54221 Text feature [example] present in test data point [True]
# 54227 Text feature [could] present in test data point [True]
# 54229 Text feature [structural] present in test data point [True]
# 54231 Text feature [based] present in test data point [True]
# 54233 Text feature [significant] present in test data point [True]
# 54235 Text feature [http] present in test data point [True]
# 54237 Text feature [thus] present in test data point [True]
# 54238 Text feature [including] present in test data point [True]
# 54240 Text feature [37] present in test data point [True]
# 54241 Text feature [several] present in test data point [True]
# 54243 Text feature [previously] present in test data point [True]
# 54244 Text feature [described] present in test data point [True]
# 54246 Text feature [acid] present in test data point [True]
# 54247 Text feature [well] present in test data point [True]
# 54248 Text feature [specificity] present in test data point [True]
# 54249 Text feature [significantly] present in test data point [True]
# 54250 Text feature [however] present in test data point [True]
# 54254 Text feature [majority] present in test data point [True]
# 54255 Text feature [2c] present in test data point [True]
# 54257 Text feature [performed] present in test data point [True]
# 54260 Text feature [many] present in test data point [True]
# 54261 Text feature [cancer] present in test data point [True]
# 54263 Text feature [consistent] present in test data point [True]
# 54264 Text feature [domains] present in test data point [True]
# 54265 Text feature [following] present in test data point [True]
# 54266 Text feature [shows] present in test data point [True]
# 54269 Text feature [critical] present in test data point [True]
# 54270 Text feature [given] present in test data point [True]
# 54272 Text feature [predicted] present in test data point [True]
# 54274 Text feature [change] present in test data point [True]
# 54275 Text feature [revealed] present in test data point [True]
# 54276 Text feature [genetic] present in test data point [True]
# 54277 Text feature [figure] present in test data point [True]
# 54279 Text feature [nonsense] present in test data point [True]
# 54280 Text feature [provides] present in test data point [True]
# 54281 Text feature [together] present in test data point [True]
# 54283 Text feature [identify] present in test data point [True]
# 54288 Text feature [complex] present in test data point [True]
# 54291 Text feature [addition] present in test data point [True]
# 54293 Text feature [directly] present in test data point [True]
# 54295 Text feature [within] present in test data point [True]
# 54296 Text feature [discussion] present in test data point [True]
# 54297 Text feature [either] present in test data point [True]
# 54298 Text feature [different] present in test data point [True]
# 54299 Text feature [may] present in test data point [True]
# 54300 Text feature [similar] present in test data point [True]
# 54301 Text feature [genes] present in test data point [True]
# 54302 Text feature [regions] present in test data point [True]
# 54306 Text feature [highly] present in test data point [True]
# 54307 Text feature [additional] present in test data point [True]
# 54308 Text feature [likely] present in test data point [True]
# 54310 Text feature [data] present in test data point [True]
# 54313 Text feature [lower] present in test data point [True]
# 54315 Text feature [expected] present in test data point [True]
# 54316 Text feature [central] present in test data point [True]
# 54317 Text feature [shown] present in test data point [True]
# 54318 Text feature [result] present in test data point [True]
# 54319 Text feature [ability] present in test data point [True]
# 54321 Text feature [whether] present in test data point [True]
# 54322 Text feature [gene] present in test data point [True]
# 54323 Text feature [used] present in test data point [True]
# 54325 Text feature [also] present in test data point [True]
# 54326 Text feature [structure] present in test data point [True]
# 54331 Text feature [previous] present in test data point [True]
# 54332 Text feature [using] present in test data point [True]
# 54333 Text feature [results] present in test data point [True]
# 54334 Text feature [table] present in test data point [True]
# 54335 Text feature [identified] present in test data point [True]
# 54337 Text feature [present] present in test data point [True]
# 54338 Text feature [determined] present in test data point [True]
# 54339 Text feature [five] present in test data point [True]
# 54340 Text feature [large] present in test data point [True]
# 54342 Text feature [proteins] present in test data point [True]
# 54344 Text feature [effect] present in test data point [True]
# 54345 Text feature [form] present in test data point [True]
# 54346 Text feature [changes] present in test data point [True]
# 54347 Text feature [specific] present in test data point [True]
# 54349 Text feature [surface] present in test data point [True]
# 54350 Text feature [functions] present in test data point [True]
# 54351 Text feature [analysis] present in test data point [True]
# 54352 Text feature [three] present in test data point [True]
# 54354 Text feature [loss] present in test data point [True]
# 54355 Text feature [involved] present in test data point [True]
# 54356 Text feature [indicated] present in test data point [True]
# 54358 Text feature [containing] present in test data point [True]
# 54359 Text feature [therefore] present in test data point [True]
# 54360 Text feature [binding] present in test data point [True]
# 54361 Text feature [least] present in test data point [True]
# 54362 Text feature [terminal] present in test data point [True]
# 54363 Text feature [possible] present in test data point [True]
# 54364 Text feature [acids] present in test data point [True]
# 54365 Text feature [amino] present in test data point [True]
# 54366 Text feature [six] present in test data point [True]
# 54367 Text feature [four] present in test data point [True]
# 54368 Text feature [sequence] present in test data point [True]
# 54369 Text feature [wild] present in test data point [True]
# 54372 Text feature [region] present in test data point [True]
# 54373 Text feature [one] present in test data point [True]
# 54374 Text feature [type] present in test data point [True]
# 54376 Text feature [affect] present in test data point [True]
# 54377 Text feature [two] present in test data point [True]
# 54378 Text feature [protein] present in test data point [True]
# 54379 Text feature [function] present in test data point [True]
# Out of the top  10  features  1062 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 10
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0813 0.0773 0.0131 0.1033 0.0376 0.0338 0.6451 0.0045 0.0041]]
# Actual Class : 6
# --------------------------------------------------
# Out of the top  10  features  0 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.1026035910209444
# for alpha = 11
# Log Loss : 1.0881076677809127
# for alpha = 15
# Log Loss : 1.0701781960874739
# for alpha = 21
# Log Loss : 1.0651367339124325
# for alpha = 31
# Log Loss : 1.0784979552352814
# for alpha = 41
# Log Loss : 1.083433236659503
# for alpha = 51
# Log Loss : 1.0879574973529211
# for alpha = 99
# Log Loss : 1.113252403456353
# For values of best alpha =  21 The train log loss is: 0.7320337252736104
# For values of best alpha =  21 The cross validation log loss is: 1.0651367339124325
# For values of best alpha =  21 The test log loss is: 1.0272626832295424

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0651367339124325
# Number of mis-classified points : 0.38345864661654133
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point: 1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 4
# Actual Class : 4
# The  21  nearest neighbours of the test points belongs to classes [4 4 4 4 4 4 4 1 4 4 4 4 4 4 4 4 4 4 4 4 4]
# Fequency of nearest points : Counter({4: 20, 1: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point: 2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 6
# the k value for knn is 21 and the nearest neighbours of the test points belongs to classes [7 7 7 7 7 7 7 7 7 7 2 2 7 7 6 7 7 7 7 7 5]
# Fequency of nearest points : Counter({7: 17, 2: 2, 6: 1, 5: 1})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2839656133524318
# for alpha = 1e-05
# Log Loss : 1.2681855780801075
# for alpha = 0.0001
# Log Loss : 1.1691626546073377
# for alpha = 0.001
# Log Loss : 1.1476282857983757
# for alpha = 0.01
# Log Loss : 1.1782975219918794
# for alpha = 0.1
# Log Loss : 1.4800187049841873
# for alpha = 1
# Log Loss : 1.699919496712389
# for alpha = 10
# Log Loss : 1.729191418432552
# for alpha = 100
# Log Loss : 1.732314400099782
# For values of best alpha =  0.001 The train log loss is: 0.5127773475931812
# For values of best alpha =  0.001 The cross validation log loss is: 1.1476282857983757
# For values of best alpha =  0.001 The test log loss is: 1.0569804028377174

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1476282857983757
# Number of mis-classified points : 0.3533834586466165
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[9.000e-04 1.000e-04 0.000e+00 9.906e-01 0.000e+00 0.000e+00 8.000e-03
#   3.000e-04 0.000e+00]]
# Actual Class : 4
# --------------------------------------------------
# 182 Text feature [devoid] present in test data point [True]
# 189 Text feature [activating] present in test data point [True]
# 215 Text feature [instability] present in test data point [True]
# 251 Text feature [suppressor] present in test data point [True]
# 300 Text feature [mated] present in test data point [True]
# 318 Text feature [leap] present in test data point [True]
# 319 Text feature [inhibitor] present in test data point [True]
# 320 Text feature [novel] present in test data point [True]
# 337 Text feature [kinase] present in test data point [True]
# 348 Text feature [transforming] present in test data point [True]
# 398 Text feature [mislocalized] present in test data point [True]
# 402 Text feature [harboring] present in test data point [True]
# 410 Text feature [soft] present in test data point [True]
# 430 Text feature [phosphatases] present in test data point [True]
# 446 Text feature [heterozygosity] present in test data point [True]
# 449 Text feature [nonsense] present in test data point [True]
# 463 Text feature [microscopy] present in test data point [True]
# 475 Text feature [concentrations] present in test data point [True]
# 476 Text feature [yeast] present in test data point [True]
# 488 Text feature [selective] present in test data point [True]
# Out of the top  500  features  20 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0306 0.0244 0.0026 0.0472 0.0122 0.0127 0.8643 0.0034 0.0027]]
# Actual Class : 6
# --------------------------------------------------
# 101 Text feature [constitutively] present in test data point [True]
# 179 Text feature [loss] present in test data point [True]
# 219 Text feature [downstream] present in test data point [True]
# 240 Text feature [homozygous] present in test data point [True]
# 241 Text feature [activated] present in test data point [True]
# 242 Text feature [stability] present in test data point [True]
# 243 Text feature [triphosphatases] present in test data point [True]
# 266 Text feature [ligand] present in test data point [True]
# 333 Text feature [rac] present in test data point [True]
# 388 Text feature [extracellular] present in test data point [True]
# 392 Text feature [flexible] present in test data point [True]
# 437 Text feature [conserved] present in test data point [True]
# 452 Text feature [function] present in test data point [True]
# 459 Text feature [receptors] present in test data point [True]
# Out of the top  500  features  14 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3083377734514157
# for alpha = 1e-05
# Log Loss : 1.2680548093651327
# for alpha = 0.0001
# Log Loss : 1.2092268426958268
# for alpha = 0.001
# Log Loss : 1.1747500097243855
# for alpha = 0.01
# Log Loss : 1.248854173168287
# for alpha = 0.1
# Log Loss : 1.3862260780631455
# for alpha = 1
# Log Loss : 1.60373199561701
# For values of best alpha =  0.001 The train log loss is: 0.5122625382540436
# For values of best alpha =  0.001 The cross validation log loss is: 1.1747500097243855
# For values of best alpha =  0.001 The test log loss is: 1.062461369895211

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1747500097243855
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[1.200e-03 1.000e-04 0.000e+00 9.847e-01 0.000e+00 0.000e+00 1.360e-02
#   5.000e-04 0.000e+00]]
# Actual Class : 4
# --------------------------------------------------
# 190 Text feature [devoid] present in test data point [True]
# 286 Text feature [instability] present in test data point [True]
# 321 Text feature [leap] present in test data point [True]
# 358 Text feature [suppressor] present in test data point [True]
# 369 Text feature [activating] present in test data point [True]
# 444 Text feature [mated] present in test data point [True]
# 476 Text feature [erbitux] present in test data point [True]
# 496 Text feature [phosphatases] present in test data point [True]
# 498 Text feature [possesses] present in test data point [True]
# Out of the top  500  features  9 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0305 0.0243 0.0022 0.0468 0.0116 0.0119 0.8678 0.0029 0.002 ]]
# Actual Class : 6
# --------------------------------------------------
# 152 Text feature [constitutively] present in test data point [True]
# 319 Text feature [downstream] present in test data point [True]
# 322 Text feature [triphosphatases] present in test data point [True]
# 403 Text feature [activated] present in test data point [True]
# 453 Text feature [rac] present in test data point [True]
# 469 Text feature [extracellular] present in test data point [True]
# 483 Text feature [ligand] present in test data point [True]
# 491 Text feature [loss] present in test data point [True]
# 495 Text feature [expressing] present in test data point [True]
# Out of the top  500  features  9 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.2664807427457718
# for C = 0.0001
# Log Loss : 1.2532203278461114
# for C = 0.001
# Log Loss : 1.1912891815983306
# for C = 0.01
# Log Loss : 1.1834424758966042
# for C = 0.1
# Log Loss : 1.4323515991639173
# for C = 1
# Log Loss : 1.7183432392540372
# for C = 10
# Log Loss : 1.7329129483617947
# for C = 100
# Log Loss : 1.7329077769629628
# For values of best alpha =  0.01 The train log loss is: 0.7266478970877802
# For values of best alpha =  0.01 The cross validation log loss is: 1.1834424758966042
# For values of best alpha =  0.01 The test log loss is: 1.127107625990545

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1834424758966042
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[2.000e-02 1.400e-03 2.000e-04 8.260e-01 3.200e-03 6.000e-04 1.482e-01
#   4.000e-04 1.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 93 Text feature [microscopy] present in test data point [True]
# 113 Text feature [suppressor] present in test data point [True]
# 116 Text feature [mislocalized] present in test data point [True]
# 149 Text feature [instability] present in test data point [True]
# 168 Text feature [phosphatases] present in test data point [True]
# 196 Text feature [material] present in test data point [True]
# 197 Text feature [devoid] present in test data point [True]
# 209 Text feature [nonsense] present in test data point [True]
# 311 Text feature [mated] present in test data point [True]
# 330 Text feature [heterozygosity] present in test data point [True]
# 347 Text feature [ambient] present in test data point [True]
# 447 Text feature [localization] present in test data point [True]
# Out of the top  500  features  12 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0675 0.0349 0.0089 0.0979 0.0284 0.0273 0.7285 0.0028 0.0039]]
# Actual Class : 6
# --------------------------------------------------
# 80 Text feature [triphosphatases] present in test data point [True]
# 143 Text feature [constitutively] present in test data point [True]
# 201 Text feature [egf] present in test data point [True]
# 205 Text feature [expressing] present in test data point [True]
# 213 Text feature [downstream] present in test data point [True]
# 373 Text feature [ligand] present in test data point [True]
# 374 Text feature [activated] present in test data point [True]
# 461 Text feature [exchange] present in test data point [True]
# 463 Text feature [rac] present in test data point [True]
# Out of the top  500  features  9 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2508609017730925
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.1994062266796501
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2409660466930579
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.1947334558530778
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2413884474316739
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.1891020678364577
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2377696023048417
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1890551562518288
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2359494339351293
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.187241940269813
# For values of best estimator =  2000 The train log loss is: 0.6943021187547095
# For values of best estimator =  2000 The cross validation log loss is: 1.187241940269813
# For values of best estimator =  2000 The test log loss is: 1.1195601794787602

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.187241940269813
# Number of mis-classified points : 0.39473684210526316
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0676 0.0145 0.0123 0.7962 0.0298 0.0239 0.0488 0.0031 0.0038]]
# Actual Class : 4
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [activation] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 4 Text feature [tyrosine] present in test data point [True]
# 5 Text feature [inhibitor] present in test data point [True]
# 6 Text feature [activated] present in test data point [True]
# 7 Text feature [treatment] present in test data point [True]
# 8 Text feature [phosphorylation] present in test data point [True]
# 9 Text feature [constitutive] present in test data point [True]
# 10 Text feature [missense] present in test data point [True]
# 11 Text feature [erk] present in test data point [True]
# 12 Text feature [oncogenic] present in test data point [True]
# 13 Text feature [nonsense] present in test data point [True]
# 14 Text feature [suppressor] present in test data point [True]
# 15 Text feature [function] present in test data point [True]
# 16 Text feature [loss] present in test data point [True]
# 17 Text feature [signaling] present in test data point [True]
# 18 Text feature [constitutively] present in test data point [True]
# 19 Text feature [therapy] present in test data point [True]
# 20 Text feature [yeast] present in test data point [True]
# 22 Text feature [stability] present in test data point [True]
# 23 Text feature [functional] present in test data point [True]
# 24 Text feature [receptor] present in test data point [True]
# 25 Text feature [trials] present in test data point [True]
# 26 Text feature [downstream] present in test data point [True]
# 27 Text feature [kinases] present in test data point [True]
# 28 Text feature [cells] present in test data point [True]
# 29 Text feature [akt] present in test data point [True]
# 30 Text feature [3t3] present in test data point [True]
# 31 Text feature [unstable] present in test data point [True]
# 32 Text feature [mek] present in test data point [True]
# 34 Text feature [drug] present in test data point [True]
# 35 Text feature [growth] present in test data point [True]
# 36 Text feature [efficacy] present in test data point [True]
# 37 Text feature [months] present in test data point [True]
# 38 Text feature [variants] present in test data point [True]
# 39 Text feature [phospho] present in test data point [True]
# 40 Text feature [ic50] present in test data point [True]
# 42 Text feature [cell] present in test data point [True]
# 43 Text feature [mitogen] present in test data point [True]
# 44 Text feature [patients] present in test data point [True]
# 45 Text feature [pathogenic] present in test data point [True]
# 46 Text feature [inhibition] present in test data point [True]
# 47 Text feature [extracellular] present in test data point [True]
# 49 Text feature [resistance] present in test data point [True]
# 50 Text feature [advanced] present in test data point [True]
# 53 Text feature [deleterious] present in test data point [True]
# 54 Text feature [treated] present in test data point [True]
# 55 Text feature [pathogenicity] present in test data point [True]
# 56 Text feature [imatinib] present in test data point [True]
# 57 Text feature [therapeutic] present in test data point [True]
# 58 Text feature [protein] present in test data point [True]
# 59 Text feature [stimulation] present in test data point [True]
# 61 Text feature [activate] present in test data point [True]
# 62 Text feature [nsclc] present in test data point [True]
# 63 Text feature [mapk] present in test data point [True]
# 64 Text feature [lung] present in test data point [True]
# 65 Text feature [transforming] present in test data point [True]
# 66 Text feature [neutral] present in test data point [True]
# 68 Text feature [expression] present in test data point [True]
# 69 Text feature [autophosphorylation] present in test data point [True]
# 70 Text feature [doses] present in test data point [True]
# 71 Text feature [expressing] present in test data point [True]
# 72 Text feature [ras] present in test data point [True]
# 74 Text feature [harboring] present in test data point [True]
# 76 Text feature [proteins] present in test data point [True]
# 77 Text feature [pten] present in test data point [True]
# 79 Text feature [defective] present in test data point [True]
# 80 Text feature [egfr] present in test data point [True]
# 83 Text feature [erk1] present in test data point [True]
# 84 Text feature [amplification] present in test data point [True]
# 85 Text feature [response] present in test data point [True]
# 87 Text feature [trial] present in test data point [True]
# 88 Text feature [inhibited] present in test data point [True]
# 91 Text feature [oncogene] present in test data point [True]
# 92 Text feature [survival] present in test data point [True]
# 93 Text feature [factor] present in test data point [True]
# 94 Text feature [clinical] present in test data point [True]
# 95 Text feature [ligand] present in test data point [True]
# 96 Text feature [dna] present in test data point [True]
# Out of the top  100  features  81 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0995 0.0895 0.0223 0.1139 0.053  0.0479 0.5626 0.006  0.0054]]
# Actuall Class : 6
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [activation] present in test data point [True]
# 3 Text feature [inhibitors] present in test data point [True]
# 4 Text feature [tyrosine] present in test data point [True]
# 5 Text feature [inhibitor] present in test data point [True]
# 6 Text feature [activated] present in test data point [True]
# 7 Text feature [treatment] present in test data point [True]
# 8 Text feature [phosphorylation] present in test data point [True]
# 11 Text feature [erk] present in test data point [True]
# 15 Text feature [function] present in test data point [True]
# 16 Text feature [loss] present in test data point [True]
# 17 Text feature [signaling] present in test data point [True]
# 18 Text feature [constitutively] present in test data point [True]
# 20 Text feature [yeast] present in test data point [True]
# 22 Text feature [stability] present in test data point [True]
# 23 Text feature [functional] present in test data point [True]
# 24 Text feature [receptor] present in test data point [True]
# 26 Text feature [downstream] present in test data point [True]
# 27 Text feature [kinases] present in test data point [True]
# 28 Text feature [cells] present in test data point [True]
# 29 Text feature [akt] present in test data point [True]
# 32 Text feature [mek] present in test data point [True]
# 34 Text feature [drug] present in test data point [True]
# 35 Text feature [growth] present in test data point [True]
# 40 Text feature [ic50] present in test data point [True]
# 42 Text feature [cell] present in test data point [True]
# 43 Text feature [mitogen] present in test data point [True]
# 44 Text feature [patients] present in test data point [True]
# 46 Text feature [inhibition] present in test data point [True]
# 47 Text feature [extracellular] present in test data point [True]
# 49 Text feature [resistance] present in test data point [True]
# 58 Text feature [protein] present in test data point [True]
# 59 Text feature [stimulation] present in test data point [True]
# 61 Text feature [activate] present in test data point [True]
# 64 Text feature [lung] present in test data point [True]
# 68 Text feature [expression] present in test data point [True]
# 71 Text feature [expressing] present in test data point [True]
# 72 Text feature [ras] present in test data point [True]
# 74 Text feature [harboring] present in test data point [True]
# 76 Text feature [proteins] present in test data point [True]
# 79 Text feature [defective] present in test data point [True]
# 80 Text feature [egfr] present in test data point [True]
# 85 Text feature [response] present in test data point [True]
# 88 Text feature [inhibited] present in test data point [True]
# 93 Text feature [factor] present in test data point [True]
# 95 Text feature [ligand] present in test data point [True]
# Out of the top  100  features  47 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.123533489081593
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.579006617178633
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.3674020167572085
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.7312276722605695
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.6803515576105068
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.3862334173741488
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.3691845448100062
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.6829662887545902
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5282495300759285
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.4339485911449676
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2762667275726134
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.6633351861422616
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.525950108369245
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.4437723265128986
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.3352640264363589
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.6912648266552806
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.578658269010293
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.4975911185932727
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.3476081956206516
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.7140123257716626
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.5707405352901647
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5031725877274518
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.3428630945722777
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.6967009690973336
# For values of best alpha =  100 The train log loss is: 0.0609531089607512
# For values of best alpha =  100 The cross validation log loss is: 1.2762667275726136
# For values of best alpha =  100 The test log loss is: 1.1984839670645724

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.2762667275726134
# Number of mis-classified points : 0.4323308270676692
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0912 0.0297 0.0831 0.5933 0.0436 0.0507 0.019  0.0377 0.0517]]
# Actual Class : 4
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0247 0.1461 0.1558 0.0477 0.0414 0.062  0.4435 0.0512 0.0275]]
# Actual Class : 6
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

# Logistic regression
clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")


# Lr. SVM
clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")

# Naive bayes
clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.15
# Support vector machines : Log Loss: 1.72
# Naive Bayes : Log Loss: 1.30
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 1.818
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.725
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.356
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.242
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.506
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.810

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.49660433790130903
# Log loss (CV) on the stacking classifier : 1.241585506947666
# Log loss (test) on the stacking classifier : 1.1440260070773647
# Number of missclassified point : 0.3533834586466165
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.8591524713500343
# Log loss (CV) on the VotingClassifier : 1.2218114472742905
# Log loss (test) on the VotingClassifier : 1.1870672767200425
# Number of missclassified point : 0.36541353383458647
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h1>5. Assignments</h1>

# %% [markdown]
# <ol>
#     <li> Apply All the models with tf-idf features (Replace CountVectorizer with tfidfVectorizer and run the same cells)</li>
#     <li> Instead of using all the words in the dataset, use only the top 1000 words based of tf-idf values</li>
#     <li>Apply Logistic regression with CountVectorizer Features, including both unigrams and bigrams</li>
#     <li> Try any of the feature engineering techniques discussed in the course to reduce the CV and test log-loss to a value less than 1.0</li>
# </ol>
